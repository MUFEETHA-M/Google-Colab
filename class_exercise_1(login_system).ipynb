# %% [markdown]
# <a href="https://colab.research.google.com/github/MUFEETHA-M/Google-Colab/blob/main/class_exercise_1(login_system).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Account_name = "Mufee"
Password = "1234"
Balance = 1000
def login():
    user = input("Enter Account Name: ")
    pwd = input("Enter Password: ")
    if user == Account_name and pwd == Password:
        print("Login Successful\n")
        banking()
    else:
        print("Invalid Login!")
def deposit(amount):
    global Balance
    Balance += amount
    print("Deposited:", amount)
def withdraw(amount):
    global Balance
    if amount <= Balance:
        Balance -= amount
        print("Withdrawn:", amount)
    else:
        print("Insufficient Balance!")
def check_balance():
    print("Your Balance is:", Balance)
def banking():
    while True:
        print("\n1.Deposit")
        print("2.Withdraw")
        print("3.Check Balance")
        print("4.Exit")
        choice = int(input("Enter choice: "))
        if choice == 1:
            amt = int(input("Enter Amount: "))
            deposit(amt)
        elif choice == 2:
            amt = int(input("Enter Amount: "))
            withdraw(amt)
        elif choice == 3:
            check_balance()
        elif choice == 4:
            print("Thank You!")
            break
        else:
            print("Invalid Choice")
login()
# Out:
# Enter Account Name: Mufee
# Enter Password: 1234
# Login Successful
#
#
# 1.Deposit
# 2.Withdraw
# 3.Check Balance
# 4.Exit
# Enter choice: 3
# Your Balance is: 1000
#
# 1.Deposit
# 2.Withdraw
# 3.Check Balance
# 4.Exit
